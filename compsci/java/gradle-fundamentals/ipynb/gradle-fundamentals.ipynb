# %% [markdown]
# # Gradle
#
# #### gradle is a project build system  working with multiple languages on jvm

# %% [markdown]
# OSX  gradle is installed with brew

# %% [markdown]
# # Ch Introduction

# %% [markdown]
# ### running a gradle task
#
# `
# cd ~/Dropbox/cs/gcs/plural/java/gradle-fundamentals/ex/1-gradle-fundamentals-m1-exercise-files/Gradle/Simple
# localhost:Simple zimine$ ls
# build.gradle
# localhost:Simple zimine$ cat build.gradle
# task hello {
#   doLast {
#     println "Hello Gradle"
#   }
# }
# $>gradle hello
# hello
# Hello Gradle
# BUILD SUCCESSFUL
# `

# %% [markdown]
# ### Running gradle on a simples java project
#
# `cd ~Dropbox/cs/gcs/plural/java/gradle-fundamentals/ex/1-gradle-fundamentals-m1-exercise-files/Gradle/FirstJava
# $cat build.gradle
# apply plugin: 'java'
# task wrapper(type: Wrapper) {
#     gradleVersion = '2.6'
# }
# `
#
# #### which tasks ara available on java projects
# `$gradle tasks`
# :tasks
#
# ------------------------------------------------------------
# All tasks runnable from root project
# ------------------------------------------------------------
#
# Build tasks
# -----------
# assemble - Assembles the outputs of this project.
#
# build - Assembles and tests this project.
#
# buildDependents - Assembles and tests this project and all projects that depend on it.
#
# buildNeeded - Assembles and tests this project and all projects it depends on.
#
# classes - Assembles main classes.
#
# clean - Deletes the build directory.
#
# jar - Assembles a jar archive containing the main classes.
#
# testClasses - Assembles test classes.
#
# Build Setup tasks
# -----------------
# init - Initializes a new Gradle build. [incubating]
#
# Documentation tasks
# -------------------
# javadoc - Generates Javadoc API documentation for the main source code.
#
# Help tasks
# ----------
# buildEnvironment - Displays all buildscript dependencies declared in root project 'FirstJava'.
#
# components - Displays the components produced by root project 'FirstJava'. [incubating]
#
# dependencies - Displays all dependencies declared in root project 'FirstJava'.
#
# dependencyInsight - Displays the insight into a specific dependency in root project 'FirstJava'.
#
# dependentComponents - Displays the dependent components of components in root project 'FirstJava'. [incubating]
#
# help - Displays a help message.
#
# model - Displays the configuration model of root project 'FirstJava'. [incubating]
#
# projects - Displays the sub-projects of root project 'FirstJava'.
#
# properties - Displays the properties of root project 'FirstJava'.
#
# tasks - Displays the tasks runnable from root project 'FirstJava'.
#
# Verification tasks
# ------------------
# check - Runs all checks.
#
# test - Runs the unit tests.
#
# Rules
# -----
# Pattern: clean<TaskName>: Cleans the output files of a task.
#
# Pattern: build<ConfigurationName>: Assembles the artifacts of a configuration.
#
# Pattern: upload<ConfigurationName>: Assembles and uploads the artifacts belonging to a configuration.
#
# To see all tasks and more detail, run gradle tasks --all
#
# To see more detail about a task, run gradle help --task <task>
#
# BUILD SUCCESSFUL
#
# Total time: 2.169 secs
#
# ## Building a java project
# `$gradle build`
#
# :compileJava
#
# :processResources UP-TO-DATE
#
# :classes
#
# :jar
#
# :assemble
#
# :compileTestJava UP-TO-DATE
#
# :processTestResources UP-TO-DATE
#
# :testClasses UP-TO-DATE
#
# :test UP-TO-DATE
#
# :check UP-TO-DATE
#
# :build
#
# BUILD SUCCESSFUL
#
# Total time: 1.698 secs
#
# #### a build folder appears in the project containing
# * classes  folder with compiled classes
# * lib folder with project's jar
#
# ## Cleaning the project
# `$gradle clean`
#
# removes this folder
#
# ## Testing the project on main class
# `$ java -cp build/classes/main/  com.pluralsight.Hello`
#
# Hello World!
#
# ## Creating a wrapper
# `$gradle wrapper`
#
# This creates 2 scripts gradlew and gradlew.bat
#
# Executing the script downloads the gradle of the specified version in build.gradle
# and then you can use gradlew to run any tasks
#
# ### advantage:  with your build.gradle you can have a gradle binary of the specified version

# %% [markdown]
# # ch Basic Gradle Tasks
#
# ### A task
#     * code that gradle executes
#     * has lifecycle
#     * has properties
#     * has actions
#     * has dependenicies (1 task can be dependent on another)
